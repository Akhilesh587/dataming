# %%
#Import Libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Import Dataset - Car_sales.csv
cars = pd.read_csv('Car_sales.csv')
cars.head(5)
# Out:
#   Manufacturer    Model Vehicle_type  Price_in_thousands  Engine_size  \
# 0        Acura  Integra    Passenger               21.50          1.8
# 1        Acura       TL    Passenger               28.40          3.2
# 2        Acura       CL    Passenger                 NaN          3.2
# 3        Acura       RL    Passenger               42.00          3.5
# 4         Audi       A4    Passenger               23.99          1.8
#
#    Horsepower  Wheelbase  Width  Length  Curb_weight  Fuel_capacity  \
# 0       140.0      101.2   67.3   172.4        2.639           13.2
# 1       225.0      108.1   70.3   192.9        3.517           17.2
# 2       225.0      106.9   70.6   192.0        3.470           17.2
# 3       210.0      114.6   71.4   196.6        3.850           18.0
# 4       150.0      102.6   68.2   178.0        2.998           16.4
#
#    Fuel_efficiency  Power_perf_factor  Sales_in_thousands  __year_resale_value
# 0             28.0          58.280150              16.919               16.360
# 1             25.0          91.370778              39.384               19.875
# 2             26.0                NaN              14.114               18.225
# 3             22.0          91.389779               8.588               29.725
# 4             27.0          62.777639              20.397               22.255

# %%
#Read top five values
cars.head(10)
# Out:
#   Manufacturer    Model Vehicle_type  Price_in_thousands  Engine_size  \
# 0        Acura  Integra    Passenger               21.50          1.8
# 1        Acura       TL    Passenger               28.40          3.2
# 2        Acura       CL    Passenger                 NaN          3.2
# 3        Acura       RL    Passenger               42.00          3.5
# 4         Audi       A4    Passenger               23.99          1.8
# 5         Audi       A6    Passenger               33.95          2.8
# 6         Audi       A8    Passenger               62.00          4.2
# 7          BMW     323i    Passenger               26.99          2.5
# 8          BMW     328i    Passenger               33.40          2.8
# 9          BMW     528i    Passenger               38.90          2.8
#
#    Horsepower  Wheelbase  Width  Length  Curb_weight  Fuel_capacity  \
# 0       140.0      101.2   67.3   172.4        2.639           13.2
# 1       225.0      108.1   70.3   192.9        3.517           17.2
# 2       225.0      106.9   70.6   192.0        3.470           17.2
# 3       210.0      114.6   71.4   196.6        3.850           18.0
# 4       150.0      102.6   68.2   178.0        2.998           16.4
# 5       200.0      108.7   76.1   192.0        3.561           18.5
# 6       310.0      113.0   74.0   198.2        3.902           23.7
# 7       170.0      107.3   68.4   176.0        3.179           16.6
# 8       193.0      107.3   68.5   176.0        3.197           16.6
# 9       193.0      111.4   70.9   188.0        3.472           18.5
#
#    Fuel_efficiency  Power_perf_factor  Sales_in_thousands  __year_resale_value
# 0             28.0          58.280150              16.919               16.360
# 1             25.0          91.370778              39.384               19.875
# 2             26.0                NaN              14.114               18.225
# 3             22.0          91.389779               8.588               29.725
# 4             27.0          62.777639              20.397               22.255
# 5             22.0          84.565105              18.780               23.555
# 6             21.0         134.656858               1.380               39.000
# 7             26.0          71.191207              19.747                  NaN
# 8             24.0          81.877069               9.231               28.675
# 9             25.0          83.998724              17.527               36.125

# %%
#Print DataFrame info - data types of each column
cars.dtypes
# Out:
# Manufacturer            object
# Model                   object
# Vehicle_type            object
# Price_in_thousands     float64
# Engine_size            float64
# Horsepower             float64
# Wheelbase              float64
# Width                  float64
# Length                 float64
# Curb_weight            float64
# Fuel_capacity          float64
# Fuel_efficiency        float64
# Power_perf_factor      float64
# Sales_in_thousands     float64
# __year_resale_value    float64
# dtype: object

# %%
#Print number of rows and columns
cars.shape
# Out:
# (159, 15)

# %%
#Drop duplicate rows - if any

cars=cars.drop_duplicates(keep='first')
cars.shape
# Out:
# (157, 15)

# %%
#Print number of rows and columns after dropping duplicates

cars.shape
# Out:
# (157, 15)

# %%
#Print summary statistics for numerical variables

cars.describe()
# Out:
#        Price_in_thousands  Engine_size  Horsepower   Wheelbase       Width  \
# count          155.000000   156.000000  156.000000  156.000000  156.000000
# mean            27.390755     3.060897  185.948718  107.487179   71.150000
# std             14.351653     1.044653   56.700321    7.641303    3.451872
# min              9.235000     1.000000   55.000000   92.600000   62.600000
# 25%             18.017500     2.300000  149.500000  103.000000   68.400000
# 50%             22.799000     3.000000  177.500000  107.000000   70.550000
# 75%             31.947500     3.575000  215.000000  112.200000   73.425000
# max             85.500000     8.000000  450.000000  138.700000   79.900000
#
#            Length  Curb_weight  Fuel_capacity  Fuel_efficiency  \
# count  156.000000   155.000000     156.000000       154.000000
# mean   187.343590     3.378026      17.951923        23.844156
# std     13.431754     0.630502       3.887921         4.282706
# min    149.400000     1.895000      10.300000        15.000000
# 25%    177.575000     2.971000      15.800000        21.000000
# 50%    187.900000     3.342000      17.200000        24.000000
# 75%    196.125000     3.799500      19.575000        26.000000
# max    224.500000     5.572000      32.000000        45.000000
#
#        Power_perf_factor  Sales_in_thousands  __year_resale_value
# count         155.000000          157.000000           121.000000
# mean           77.043591           52.998076            18.072975
# std            25.142664           68.029422            11.453384
# min            23.276272            0.110000             5.160000
# 25%            60.407707           14.114000            11.260000
# 50%            72.030917           29.450000            14.180000
# 75%            89.414878           67.956000            19.875000
# max           188.144323          540.561000            67.550000

# %%
#Print number of missing values in each column

cars.isnull().sum()
# Out:
# Manufacturer            0
# Model                   1
# Vehicle_type            0
# Price_in_thousands      2
# Engine_size             1
# Horsepower              1
# Wheelbase               1
# Width                   1
# Length                  1
# Curb_weight             2
# Fuel_capacity           1
# Fuel_efficiency         3
# Power_perf_factor       2
# Sales_in_thousands      0
# __year_resale_value    36
# dtype: int64

# %%
#Drop the column with most missing values

cars.drop(['__year_resale_value'],axis=1,inplace=True)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-a4d9f16aa2b2> in <module>
# ----> 1 cars.shape
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
#Drop the row(s) with categorical missing values
cars=cars[pd.notnull(cars['Model'])]
cars.isna().sum()
# Out:
# Manufacturer          0
# Model                 0
# Vehicle_type          0
# Price_in_thousands    2
# Engine_size           1
# Horsepower            1
# Wheelbase             1
# Width                 1
# Length                1
# Curb_weight           2
# Fuel_capacity         1
# Fuel_efficiency       3
# Power_perf_factor     2
# Sales_in_thousands    0
# dtype: int64

# %%
#Impute the rows with numerical missing values 
#from sklearn.preprocessing import Imputer
#fill_NaN = Imputer(missing_values='NaN', strategy='mean', axis=1)
#imputed_DF = pd.DataFrame(fill_NaN.fit_transform(cars))
#imputed_DF.columns = DF.columns
#imputed_DF.index = DF.index
cars['Price_in_thousands'].fillna(cars['Price_in_thousands'].mean(),inplace=True)
cars['Engine_size'].fillna(cars['Engine_size'].mean(),inplace=True)
cars['Horsepower'].fillna(cars['Horsepower'].mean(),inplace=True)
cars['Wheelbase'].fillna(cars['Wheelbase'].mean(),inplace=True)
cars['Width'].fillna(cars['Width'].mean(),inplace=True)
cars['Length'].fillna(cars['Length'].mean(),inplace=True)
cars['Curb_weight'].fillna(cars['Curb_weight'].mean(),inplace=True)
cars['Fuel_capacity'].fillna(cars['Fuel_capacity'].mean(),inplace=True)
cars['Fuel_efficiency'].fillna(cars['Fuel_efficiency'].mean(),inplace=True)
cars['Power_perf_factor'].fillna(cars['Power_perf_factor'].mean(),inplace=True)
cars['Sales_in_thousands'].fillna(cars['Sales_in_thousands'].mean(),inplace=True)
#cars['_y'].fillna(cars['Price_in_thousands'].mean(),inplace=True)
cars.isna().sum()
# Out:
# Manufacturer          0
# Model                 0
# Vehicle_type          0
# Price_in_thousands    0
# Engine_size           0
# Horsepower            0
# Wheelbase             0
# Width                 0
# Length                0
# Curb_weight           0
# Fuel_capacity         0
# Fuel_efficiency       0
# Power_perf_factor     0
# Sales_in_thousands    0
# dtype: int64

# %%
#Sort the data w.r.t Price - find the details of the most and the least expensive cars
cars_sort=cars.sort_values(by=['Price_in_thousands'],ascending=False)
cars_sort.head(4)
# Out:
#     Manufacturer           Model Vehicle_type  Price_in_thousands  \
# 101   Mercedes-B           CL500    Passenger               85.50
# 97    Mercedes-B        SL-Class    Passenger               82.60
# 128      Porsche  Carrera Cabrio    Passenger               74.97
# 127      Porsche   Carrera Coupe    Passenger               71.02
#
#      Engine_size  Horsepower  Wheelbase  Width  Length  Curb_weight  \
# 101          5.0       302.0      113.6   73.1   196.6        4.115
# 97           5.0       302.0       99.0   71.3   177.1        4.125
# 128          3.4       300.0       92.6   69.5   174.5        3.075
# 127          3.4       300.0       92.6   69.5   174.5        3.032
#
#      Fuel_capacity  Fuel_efficiency  Power_perf_factor  Sales_in_thousands
# 101           23.2             20.0         141.100985               0.954
# 97            21.1             20.0         139.982294               3.311
# 128           17.0             23.0         135.914710               1.866
# 127           17.0             21.0         134.390975               1.280

# %%
#Write a function to find min and max values of any column
cars.min()
cars.max()
# Out:
# Manufacturer              Volvo
# Model                    Xterra
# Vehicle_type          Passenger
# Price_in_thousands         85.5
# Engine_size                   8
# Horsepower                  450
# Wheelbase                 138.7
# Width                      79.9
# Length                    224.5
# Curb_weight               5.572
# Fuel_capacity                32
# Fuel_efficiency              45
# Power_perf_factor       188.144
# Sales_in_thousands      540.561
# dtype: object

# %%
#Call the above function to find min max of horse power, length,  fuel efficiency

cars['Horsepower'].min()
cars['Horsepower'].max()
cars['Length'].min()
cars['Length'].max()
# Out:
# 224.5

# %%
# Out:
# Manufacturer               Volvo
# Vehicle_type           Passenger
# Price_in_thousands          85.5
# Engine_size                    8
# Horsepower                   450
# Wheelbase                  138.7
# Width                       79.9
# Length                     224.5
# Curb_weight                5.572
# Fuel_capacity                 32
# Fuel_efficiency               45
# Power_perf_factor        188.144
# Sales_in_thousands       540.561
# __year_resale_value        67.55
# dtype: object

# %%
#Plot histogrma of cotinuous numerical variable - Price sales, horse power,  fuel efficiency using subplot

plt.subplot(221)
plt.hist(cars['Price_in_thousands'])
plt.xlabel('Price_in_thousands')
plt.subplot(222)
plt.hist(cars['Sales_in_thousands'])
plt.xlabel('Sales_in_thousands')
plt.subplot(223)
plt.hist(cars['Fuel_efficiency'])
plt.xlabel('Horsepower')
plt.subplot(224)
plt.hist(cars['Horsepower'])
plt.xlabel('Horsepower')

plt.show()

# %%
#Plot probability density distribution of cotinuous numerical variable - Length
sns.distplot(cars['Length'])
# Out:
# /home/akhilesh/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#Count by category - group by manufacturer
cars.groupby('Manufacturer').size()
# Out:
# Manufacturer
# Acura          4
# Audi           3
# BMW            3
# Buick          4
# Cadillac       6
# Chevrolet      9
# Chrysler       7
# Dodge         11
# Ford          12
# Honda          5
# Hyundai        3
# Infiniti       1
# Jaguar         1
# Jeep           3
# Lexus          6
# Lincoln        3
# Mercedes-B     9
# Mercury        6
# Mitsubishi     7
# Nissan         7
# Oldsmobile     6
# Plymouth       4
# Pontiac        6
# Porsche        3
# Saab           2
# Saturn         5
# Subaru         2
# Toyota         9
# Volkswagen     6
# Volvo          5
# dtype: int64

# %%
#Select all numeroical variables
cars_num=cars.select_dtypes(['int64','float64'])
cars.head(6)
# Out:
#   Manufacturer    Model Vehicle_type  Price_in_thousands  Engine_size  \
# 0        Acura  Integra    Passenger           21.500000          1.8
# 1        Acura       TL    Passenger           28.400000          3.2
# 2        Acura       CL    Passenger           27.455301          3.2
# 3        Acura       RL    Passenger           42.000000          3.5
# 4         Audi       A4    Passenger           23.990000          1.8
# 5         Audi       A6    Passenger           33.950000          2.8
#
#    Horsepower  Wheelbase  Width  Length  Curb_weight  Fuel_capacity  \
# 0       140.0      101.2   67.3   172.4        2.639           13.2
# 1       225.0      108.1   70.3   192.9        3.517           17.2
# 2       225.0      106.9   70.6   192.0        3.470           17.2
# 3       210.0      114.6   71.4   196.6        3.850           18.0
# 4       150.0      102.6   68.2   178.0        2.998           16.4
# 5       200.0      108.7   76.1   192.0        3.561           18.5
#
#    Fuel_efficiency  Power_perf_factor  Sales_in_thousands
# 0             28.0          58.280150              16.919
# 1             25.0          91.370778              39.384
# 2             26.0          77.368739              14.114
# 3             22.0          91.389779               8.588
# 4             27.0          62.777639              20.397
# 5             22.0          84.565105              18.780

# %%
#Plot histogram of all numerical variables at a time (single command)

cars_num.hist()
plt.show()

# %%
#Print correlation coefficient value of price and sales

cars.corr()['Price_in_thousands'][:]
# Out:
# Price_in_thousands    1.000000
# Engine_size           0.622271
# Horsepower            0.837515
# Wheelbase             0.107083
# Width                 0.324155
# Length                0.154652
# Curb_weight           0.522224
# Fuel_capacity         0.422420
# Fuel_efficiency      -0.489704
# Power_perf_factor     0.897057
# Sales_in_thousands   -0.308760
# Name: Price_in_thousands, dtype: float64

# %%
#Plot correlation of price and sales using scatterplot

plt.scatter(cars['Price_in_thousands'],cars['Sales_in_thousands'])

# %%
#Do pair plot of all numerical variables

sns.pairplot(cars_num)
plt.show()

# %%
#Do Box plot of Sales of different Manufacturers

sns.boxplot(x=cars.Manufacturer,y=cars.Price_in_thousands)

# %%
#Do Box plot of other numerical variables w.r.t Manufacturer

# %%
#Divide the data into input and output - y = Sales in thousand, X = all other variables

X=cars.iloc[:,:-1].values
Y=cars.iloc[:,13].values

# %%
#Encode categorical varible Vehicle type using one-hot encoder

from sklearn.preprocessing import LabelEncoder,OneHotEncoder
lbl_X=LabelEncoder()
X[:,0]=lbl_X.fit_transform(X[:,0])
X[:,1]=lbl_X.fit_transform(X[:,1])
X[:,2]=lbl_X.fit_transform(X[:,2])
X
# Out:
# array([[0, 79, 1, ..., 13.2, 28.0, 58.28014952],
#        [0, 143, 1, ..., 17.2, 25.0, 91.37077766],
#        [0, 25, 1, ..., 17.2, 26.0, 77.36873868224359],
#        ...,
#        [29, 148, 1, ..., 17.9, 25.0, 71.1559776],
#        [29, 24, 1, ..., 18.5, 23.0, 101.6233572],
#        [29, 126, 1, ..., 21.1, 24.0, 85.73565451]], dtype=object)

# %%
#Encode other categorical variables using label encoder

oneHot=OneHotEncoder(categorical_features=[2])
X=oneHot.fit_transform(X).toarray()
# Out:
# /home/akhilesh/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/_encoders.py:368: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# /home/akhilesh/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/_encoders.py:390: DeprecationWarning: The 'categorical_features' keyword is deprecated in version 0.20 and will be removed in 0.22. You can use the ColumnTransformer instead.
#   "use the ColumnTransformer instead.", DeprecationWarning)
# array([[  0.        ,   1.        ,   1.        , ...,  13.2       ,
#          28.        ,  58.28014952],
#        [  0.        ,   1.        ,   1.        , ...,  17.2       ,
#          25.        ,  91.37077766],
#        [  0.        ,   1.        ,   1.        , ...,  17.2       ,
#          26.        ,  77.36873868],
#        ...,
#        [  1.        ,   0.        ,   1.        , ...,  17.9       ,
#          25.        ,  71.1559776 ],
#        [  1.        ,   0.        ,   1.        , ...,  18.5       ,
#          23.        , 101.6233572 ],
#        [  1.        ,   0.        ,   1.        , ...,  21.1       ,
#          24.        ,  85.73565451]])

# %%
#Split the data set into train and test set 70% - train set 30% - test set
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.3,random_state=0)

# %%
#Apply feature scaling on numerical variables

from sklearn.preprocessing import StandardScaler
sc_x=StandardScaler()
x_train=sc_x.fit_transform(x_train)
x_test=sc_x.fit_transform(x_test)
x_test
# Out:
# array([[ 0.        ,  0.        , -4.79583152, ..., -0.39769498,
#          0.46896126, -0.2697778 ],
#        [ 0.        ,  0.        ,  0.20851441, ...,  0.95865422,
#         -0.85301452, -1.01424395],
#        [ 0.        ,  0.        ,  0.20851441, ...,  0.079539  ,
#         -0.28645347,  0.8445435 ],
#        ...,
#        [ 0.        ,  0.        ,  0.20851441, ...,  0.73259602,
#         -0.85301452,  0.1590582 ],
#        [ 0.        ,  0.        ,  0.20851441, ..., -0.54840045,
#          0.0912539 , -0.32747465],
#        [ 0.        ,  0.        ,  0.20851441, ...,  0.58189055,
#         -0.85301452,  0.04798289]])

# %%
#Apply other Visulaization techniques that you have learnt from the videos

plt.pie(cars.groupby('Manufacturer').size(),labels=cars.groupby('Manufacturer').size())
plt.show()
